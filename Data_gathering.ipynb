# %% [markdown]
# # Obtaining the data

# %% [markdown]
# ## 1. Fetching the IDs
#
# I have managed to get an API key to ESIOS, the platform that holds the data from the electrical grid in Spain. Now I need to identify which IDs provide the data that I'm looking for. Which is total demand, total generation, and generation by each type of source.*texto en cursiva*

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# 1. Setup
ESIOS_TOKEN = "f1718d2123caf94384b20e9ed9aeee23c02573a0769603600fe9c2d9c3853b71"
headers = {
    "Accept": "application/json; application/vnd.esios-api-v1+json",
    "Content-Type": "application/json",
    "x-api-key": ESIOS_TOKEN
}

# 2. Define Test Date (Yesterday)
yesterday = datetime.now() - timedelta(days=1)
start_date = yesterday.replace(hour=0, minute=0, second=0).strftime('%Y-%m-%dT%H:%M:%S')
end_date = yesterday.replace(hour=23, minute=59, second=59).strftime('%Y-%m-%dT%H:%M:%S')

print(f"🔎 Exhaustive Search for Solar/Wind Indicators (Testing date: {yesterday.strftime('%Y-%m-%d')})...")

# 3. Fetch All Indicators
url = "https://api.esios.ree.es/indicators"
try:
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    all_indicators = response.json()['indicators']
    print(f"   ✅ Fetched {len(all_indicators)} total indicators.")
except Exception as e:
    print(f"   ❌ Failed to fetch indicator list: {e}")
    all_indicators = []

# 4. Filter Candidates
keywords = ["solar", "fotovoltaica", "eólica", "eolica", "wind"]
candidates = []

for ind in all_indicators:
    name_lower = ind['name'].lower()
    if any(k in name_lower for k in keywords):
        candidates.append(ind)

print(f"   👉 Found {len(candidates)} candidates matching keywords.")

# 5. Validate Candidates
valid_indicators = []

print("\n⚡ Verifying data availability for candidates (this may take a moment)...")
for ind in candidates:
    ind_id = ind['id']
    name = ind['name']

    url_ind = f"https://api.esios.ree.es/indicators/{ind_id}"
    params = {
        "start_date": start_date,
        "end_date": end_date
        # Intentionally omitting geo_ids to cast a wide net
    }

    try:
        r = requests.get(url_ind, headers=headers, params=params)
        if r.status_code == 200:
            data = r.json()
            values = data['indicator']['values']
            if values:
                count = len(values)
                print(f"   ✅ [WORKING] ID {ind_id}: {name} ({count} values)")
                valid_indicators.append({"id": ind_id, "name": name, "count": count})
    except Exception:
        pass

# 6. Summary
print("\n🏆 Final Verified IDs:")
if valid_indicators:
    df_valid = pd.DataFrame(valid_indicators)
    print(df_valid[['id', 'name', 'count']].to_string(index=False))
else:
    print("No working indicators found.")
# Out:
# 🔎 Exhaustive Search for Solar/Wind Indicators (Testing date: 2025-12-09)...
#    ✅ Fetched 1988 total indicators.
#    👉 Found 111 candidates matching keywords.
#
# ⚡ Verifying data availability for candidates (this may take a moment)...
#    ✅ [WORKING] ID 12: Generación programada PBF Eólica terrestre (24 values)
#    ✅ [WORKING] ID 13: Generación programada PBF Eólica marina (24 values)
#    ✅ [WORKING] ID 14: Generación programada PBF Solar fotovoltaica (24 values)
#    ✅ [WORKING] ID 15: Generación programada PBF Solar térmica (24 values)
#    ✅ [WORKING] ID 47: Generación programada PVP Eólica terrestre (24 values)
#    ✅ [WORKING] ID 48: Generación programada PVP Eólica marina (24 values)
#    ✅ [WORKING] ID 49: Generación programada PVP Solar fotovoltaica (24 values)
#    ✅ [WORKING] ID 50: Generación programada PVP Solar térmica (24 values)
#    ✅ [WORKING] ID 82: Generación programada P48 Eólica terrestre (96 values)
#    ✅ [WORKING] ID 83: Generación programada P48 Eólica marina (96 values)
#    ✅ [WORKING] ID 84: Generación programada P48 Solar fotovoltaica (96 values)
#    ✅ [WORKING] ID 85: Generación programada P48 Solar térmica (96 values)
#    ✅ [WORKING] ID 117: Generación programada PHF1 Eólica terrestre (24 values)
#    ✅ [WORKING] ID 118: Generación programada PHF1 Eólica marina (24 values)
#    ✅ [WORKING] ID 119: Generación programada PHF1 Solar fotovoltaica (24 values)
#    ✅ [WORKING] ID 120: Generación programada PHF1 Solar térmica (24 values)
#    ✅ [WORKING] ID 152: Generación programada PHF2 Eólica terrestre (24 values)
#    ✅ [WORKING] ID 153: Generación programada PHF2 Eólica marina (24 values)
#    ✅ [WORKING] ID 154: Generación programada PHF2 Solar fotovoltaica (24 values)
#    ✅ [WORKING] ID 155: Generación programada PHF2 Solar térmica (24 values)
#    ✅ [WORKING] ID 187: Generación programada PHF3 Eólica terrestre (12 values)
#    ✅ [WORKING] ID 188: Generación programada PHF3 Eólica marina (12 values)
#    ✅ [WORKING] ID 189: Generación programada PHF3 Solar fotovoltaica (12 values)
#    ✅ [WORKING] ID 190: Generación programada PHF3 Solar térmica (12 values)
#    ✅ [WORKING] ID 369: Demanda programada P48 Corrección eólica (96 values)
#    ✅ [WORKING] ID 370: Demanda programada P48 Corrección solar (37 values)
#    ✅ [WORKING] ID 432: Programa bilateral PBF Eólica terrestre (24 values)
#    ✅ [WORKING] ID 434: Programa bilateral PBF Solar fotovoltaica (11 values)
#    ✅ [WORKING] ID 435: Programa bilateral PBF Solar térmica (10 values)
#    ✅ [WORKING] ID 541: Previsión de la producción eólica peninsular (96 values)
#    ✅ [WORKING] ID 542: Generación prevista Solar fotovoltaica (96 values)
#    ✅ [WORKING] ID 543: Generación prevista Solar térmica (96 values)
#    ✅ [WORKING] ID 551: Generación T.Real eólica (288 values)
#    ✅ [WORKING] ID 1294: Generación T.Real Solar térmica (288 values)
#    ✅ [WORKING] ID 1295: Generación T.Real Solar fotovoltaica (288 values)
#    ✅ [WORKING] ID 1411: Generación programada PHFC Eólica terrestre (24 values)
#    ✅ [WORKING] ID 1412: Generación programada PHFC Eólica marina (24 values)
#    ✅ [WORKING] ID 1413: Generación programada PHFC Solar fotovoltaica (24 values)
#    ✅ [WORKING] ID 1414: Generación programada PHFC Solar térmica (24 values)
#    ✅ [WORKING] ID 1745: Generación T.Real eólica SNP (2016 values)
#    ✅ [WORKING] ID 1748: Generación T.Real solar fotovoltaica SNP (2016 values)
#    ✅ [WORKING] ID 1777: Previsión diaria D+1 eólica (24 values)
#    ✅ [WORKING] ID 1778: Previsión intradiaria H+3 eólica (24 values)
#    ✅ [WORKING] ID 1779: Previsión diaria D+1 fotovoltaica (24 values)
#    ✅ [WORKING] ID 1780: Previsión intradiaria H+3 fotovoltaica (24 values)
#    ✅ [WORKING] ID 2038: Generación T.Real eólica nacional (288 values)
#    ✅ [WORKING] ID 2044: Generación T.Real solar fotovoltaica nacional (288 values)
#    ✅ [WORKING] ID 2045: Generación T.Real solar térmica nacional (288 values)
#    ✅ [WORKING] ID 10010: Generación programada P48 Eólica (96 values)
#    ✅ [WORKING] ID 10034: Generación prevista Solar (96 values)
#    ✅ [WORKING] ID 10073: Generación programada PBF Eólica (24 values)
#    ✅ [WORKING] ID 10158: Generación programada PVP Eólica (24 values)
#    ✅ [WORKING] ID 10159: Generación programada PHF1 Eólica (24 values)
#    ✅ [WORKING] ID 10160: Generación programada PHF2 Eólica (24 values)
#    ✅ [WORKING] ID 10161: Generación programada PHF3 Eólica (12 values)
#    ✅ [WORKING] ID 10206: Generación T.Real Solar (288 values)
#    ✅ [WORKING] ID 10281: Generación programada PHFC Eólica (24 values)
#    ✅ [WORKING] ID 10358: Previsión diaria D+1 eólica más fotovoltaica (24 values)
#    ✅ [WORKING] ID 10359: Previsión intradiaria H+3 eólica más fotovoltaica (24 values)
#
# 🏆 Final Verified IDs:
#    id                                              name  count
#    12        Generación programada PBF Eólica terrestre     24
#    13           Generación programada PBF Eólica marina     24
#    14      Generación programada PBF Solar fotovoltaica     24
#    15           Generación programada PBF Solar térmica     24
#    47        Generación programada PVP Eólica terrestre     24
#    48           Generación programada PVP Eólica marina     24
#    49      Generación programada PVP Solar fotovoltaica     24
#    50           Generación programada PVP Solar térmica     24
#    82        Generación programada P48 Eólica terrestre     96
#    83           Generación programada P48 Eólica marina     96
#    84      Generación programada P48 Solar fotovoltaica     96
#    85           Generación programada P48 Solar térmica     96
#   117       Generación programada PHF1 Eólica terrestre     24
#   118          Generación programada PHF1 Eólica marina     24
#   119     Generación programada PHF1 Solar fotovoltaica     24
#   120          Generación programada PHF1 Solar térmica     24
#   152       Generación programada PHF2 Eólica terrestre     24
#   153          Generación programada PHF2 Eólica marina     24
#   154     Generación programada PHF2 Solar fotovoltaica     24
#   155          Generación programada PHF2 Solar térmica     24
#   187       Generación programada PHF3 Eólica terrestre     12
#   188          Generación programada PHF3 Eólica marina     12
#   189     Generación programada PHF3 Solar fotovoltaica     12
#   190          Generación programada PHF3 Solar térmica     12
#   369          Demanda programada P48 Corrección eólica     96
#   370           Demanda programada P48 Corrección solar     37
#   432           Programa bilateral PBF Eólica terrestre     24
#   434         Programa bilateral PBF Solar fotovoltaica     11
#   435              Programa bilateral PBF Solar térmica     10
#   541      Previsión de la producción eólica peninsular     96
#   542            Generación prevista Solar fotovoltaica     96
#   543                 Generación prevista Solar térmica     96
#   551                          Generación T.Real eólica    288
#  1294                   Generación T.Real Solar térmica    288
#  1295              Generación T.Real Solar fotovoltaica    288
#  1411       Generación programada PHFC Eólica terrestre     24
#  1412          Generación programada PHFC Eólica marina     24
#  1413     Generación programada PHFC Solar fotovoltaica     24
#  1414          Generación programada PHFC Solar térmica     24
#  1745                      Generación T.Real eólica SNP   2016
#  1748          Generación T.Real solar fotovoltaica SNP   2016
#  1777                       Previsión diaria D+1 eólica     24
#  1778                  Previsión intradiaria H+3 eólica     24
#  1779                 Previsión diaria D+1 fotovoltaica     24
#  1780            Previsión intradiaria H+3 fotovoltaica     24
#  2038                 Generación T.Real eólica nacional    288
#  2044     Generación T.Real solar fotovoltaica nacional    288
#  2045          Generación T.Real solar térmica nacional    288
# 10010                  Generación programada P48 Eólica     96
# 10034                         Generación prevista Solar     96
# 10073                  Generación programada PBF Eólica     24
# 10158                  Generación programada PVP Eólica     24
# 10159                 Generación programada PHF1 Eólica     24
# 10160                 Generación programada PHF2 Eólica     24
# 10161                 Generación programada PHF3 Eólica     12
# 10206                           Generación T.Real Solar    288
# 10281                 Generación programada PHFC Eólica     24
# 10358      Previsión diaria D+1 eólica más fotovoltaica     24
# 10359 Previsión intradiaria H+3 eólica más fotovoltaica     24

# %% [markdown]
# ## Result - IDs
#
# #### 🔧 Indicators Used & Data Status
# The following ESIOS indicators were identified and used for the 7-day data collection period:
#
# | Technology | ID Used | Indicator Name | Status |
# | :--- | :--- | :--- | :--- |
# | **Solar PV** | 1295 | Generación T.Real Solar fotovoltaica | ✅ Success |
# | **Solar Thermal** | 1294 | Generación T.Real Solar térmica | ✅ Success |
# | **Wind** | 551 | Generación T.Real eólica | ✅ Success |
# | **Nuclear** | 549 | Generación T.Real nuclear | ✅ Success |
# | **Hydro** | 546 | Generación T.Real hidráulica | ✅ Success |
# | **Coal** | 547 | Generación T.Real carbón | ✅ Success |
# | **Demand** | 460 | Previsión diaria de la demanda eléctrica peninsular | ✅ Success (Forecast) |
#
# #### 📝 Notes
# *   **Demand:** The search algorithm selected ID 460 (Daily Forecast) based on keyword matching. For future real-time analysis, ID 1293 is recommended.
# *   **Gas Combined Cycle:** ID 1746 returned no values for the requested period. This may indicate a lack of generation, a data reporting gap, or the need for an alternative geographic indicator (e.g., National vs. Peninsula).

# %% [markdown]
# ## Downloading the data and saving it to a csv file

# %% [markdown]
# Now I know what IDs I need to use to obtain the data. The API does have some strong restrictions however, to get the data I must ask for a limited amount, so I'm going to make a loop where I keep asking for small amounts and then merge all of it

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
import os
from google.colab import drive

drive.mount('/content/drive')

# Define IDs globally to avoid resolving them in every loop iteration
# IDs based on previous analysis and ESIOS documentation
ESIOS_INDICATORS = {
    "Total Generation": 10004,
    "Solar PV": 1295,
    "Solar Thermal": 1294,
    "Wind": 551,
    "Nuclear": 549,
    "Hydro": 546,
    "Coal": 547,
    "Gas Combined Cycle": 1746,
    "Demand": 1293  # Demanda real
}

def fetch_esios_data(start_date, end_date, output_folder="/content/drive/MyDrive/Deep Learning/Project 2/Spain"):
    """
    Fetches energy generation data from ESIOS for a given date range.

    Args:
        start_date (str or datetime): Start date (e.g., '2025-11-17').
        end_date (str or datetime): End date (e.g., '2025-11-27').
        output_folder (str): Directory to save the CSV file.
    """

    # 1. Configuration
    ESIOS_TOKEN = "f1718d2123caf94384b20e9ed9aeee23c02573a0769603600fe9c2d9c3853b71"
    headers = {
        "Accept": "application/json; application/vnd.esios-api-v1+json",
        "Content-Type": "application/json",
        "x-api-key": ESIOS_TOKEN
    }

    # Helper to format dates for API
    def format_date(d):
        if isinstance(d, str):
            try:
                return pd.to_datetime(d).strftime('%Y-%m-%dT%H:%M:%S')
            except:
                return d
        return d.strftime('%Y-%m-%dT%H:%M:%S')

    api_start = format_date(start_date)
    api_end = format_date(end_date)

    print(f"\n⌚ Processing Data from {api_start} to {api_end}...")

    # Use pre-defined IDs
    final_ids = ESIOS_INDICATORS

    # 2. Download Data
    print(f"\n📥 Downloading data for: {list(final_ids.keys())}")
    dfs = []

    for tech, ind_id in final_ids.items():
        url = f"https://api.esios.ree.es/indicators/{ind_id}"
        params = {
            "start_date": api_start,
            "end_date": api_end,
            "geo_ids[]": 8741 # Peninsula filter
        }

        try:
            time.sleep(0.2) # Simple rate limit
            r = requests.get(url, headers=headers, params=params)
            if r.status_code == 200:
                data = r.json()
                values = data.get('indicator', {}).get('values', [])
                if values:
                    df = pd.DataFrame(values)
                    df['datetime'] = pd.to_datetime(df['datetime'], utc=True)
                    df.set_index('datetime', inplace=True)
                    df = df[['value']].rename(columns={'value': tech})
                    # Resample to 10min
                    df = df.resample('10min').mean()
                    dfs.append(df)
                    print(f"   ✔ {tech} (ID {ind_id}): {len(df)} rows")
                else:
                    print(f"   ⚠️ {tech} (ID {ind_id}): No data returned")
            else:
                print(f"   ❌ {tech} (ID {ind_id}): API Status {r.status_code}")

        except Exception as e:
            print(f"   ❌ {tech} (ID {ind_id}): Error {e}")

    # 3. Merge and Save
    if dfs:
        final_df = pd.concat(dfs, axis=1)
        final_df.sort_index(inplace=True)

        # Ensure output directory exists
        if output_folder and not os.path.exists(output_folder):
            try:
                os.makedirs(output_folder)
            except:
                pass

        # Construct filename
        fname_start = api_start.replace(':', '-')
        fname_end = api_end.replace(':', '-')
        filename = f"spain_energy_generation_from_{fname_start}_to_{fname_end}.csv"

        if output_folder:
            full_path = os.path.join(output_folder, filename)
        else:
            full_path = filename

        try:
            final_df.to_csv(full_path)
            print(f"\n💾 Saved successfully to {full_path}")
            return final_df
        except Exception as e:
            print(f"\n⚠️ Could not save to {full_path} ({e}). Saving to local directory.")
            final_df.to_csv(filename)
            return final_df
    else:
        print("\n❌ No data collected.")
        return None

WINDOW = 10  # days per window

end_dt = datetime.now().replace(hour=23, minute=59, second=59, microsecond=0) - timedelta(days=1)

for runs in range(0, 5): # In the real implementation I did a 100 but this is just to show how it works
    start_dt = end_dt - timedelta(days=WINDOW)

    start_date = start_dt.strftime('%Y-%m-%dT%H:%M:%S')
    end_date = end_dt.strftime('%Y-%m-%dT%H:%M:%S')

    fetch_esios_data(start_date, end_date)

    # next window: move end_dt back by 10 days
    end_dt = start_dt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# ⌚ Processing Data from 2025-11-29T23:59:59 to 2025-12-09T23:59:59...
#
# 📥 Downloading data for: ['Total Generation', 'Solar PV', 'Solar Thermal', 'Wind', 'Nuclear', 'Hydro', 'Coal', 'Gas Combined Cycle', 'Demand']
#    ✔ Total Generation (ID 10004): 1440 rows
#    ✔ Solar PV (ID 1295): 1440 rows
#    ✔ Solar Thermal (ID 1294): 1440 rows
#    ✔ Wind (ID 551): 1440 rows
#    ✔ Nuclear (ID 549): 1440 rows
#    ✔ Hydro (ID 546): 1440 rows
#    ✔ Coal (ID 547): 1440 rows
#    ⚠️ Gas Combined Cycle (ID 1746): No data returned
#    ✔ Demand (ID 1293): 1440 rows
#
# 💾 Saved successfully to /content/drive/MyDrive/Deep Learning/Project 2/Spain/spain_energy_generation_from_2025-11-29T23-59-59_to_2025-12-09T23-59-59.csv
#
# ⌚ Processing Data from 2025-11-19T23:59:59 to 2025-11-29T23:59:59...
#
# 📥 Downloading data for: ['Total Generation', 'Solar PV', 'Solar Thermal', 'Wind', 'Nuclear', 'Hydro', 'Coal', 'Gas Combined Cycle', 'Demand']
#    ✔ Total Generation (ID 10004): 1440 rows
#    ✔ Solar PV (ID 1295): 1440 rows
#    ✔ Solar Thermal (ID 1294): 1440 rows
#    ✔ Wind (ID 551): 1440 rows
#    ✔ Nuclear (ID 549): 1440 rows
#    ✔ Hydro (ID 546): 1440 rows
#    ✔ Coal (ID 547): 1440 rows
#    ⚠️ Gas Combined Cycle (ID 1746): No data returned
#    ✔ Demand (ID 1293): 1440 rows
#
# 💾 Saved successfully to /content/drive/MyDrive/Deep Learning/Project 2/Spain/spain_energy_generation_from_2025-11-19T23-59-59_to_2025-11-29T23-59-59.csv
#
# ⌚ Processing Data from 2025-11-09T23:59:59 to 2025-11-19T23:59:59...
#
# 📥 Downloading data for: ['Total Generation', 'Solar PV', 'Solar Thermal', 'Wind', 'Nuclear', 'Hydro', 'Coal', 'Gas Combined Cycle', 'Demand']
#    ✔ Total Generation (ID 10004): 1440 rows
#    ✔ Solar PV (ID 1295): 1440 rows
#    ✔ Solar Thermal (ID 1294): 1440 rows
#    ✔ Wind (ID 551): 1440 rows
#    ✔ Nuclear (ID 549): 1440 rows
#    ✔ Hydro (ID 546): 1440 rows
#    ✔ Coal (ID 547): 1440 rows
#    ⚠️ Gas Combined Cycle (ID 1746): No data returned
#    ✔ Demand (ID 1293): 1440 rows
#
# 💾 Saved successfully to /content/drive/MyDrive/Deep Learning/Project 2/Spain/spain_energy_generation_from_2025-11-09T23-59-59_to_2025-11-19T23-59-59.csv
#
# ⌚ Processing Data from 2025-10-30T23:59:59 to 2025-11-09T23:59:59...
#
# 📥 Downloading data for: ['Total Generation', 'Solar PV', 'Solar Thermal', 'Wind', 'Nuclear', 'Hydro', 'Coal', 'Gas Combined Cycle', 'Demand']
#    ✔ Total Generation (ID 10004): 1440 rows
#    ✔ Solar PV (ID 1295): 1440 rows
#    ✔ Solar Thermal (ID 1294): 1440 rows
#    ✔ Wind (ID 551): 1440 rows
#    ✔ Nuclear (ID 549): 1440 rows
#    ✔ Hydro (ID 546): 1440 rows
#    ✔ Coal (ID 547): 1440 rows
#    ⚠️ Gas Combined Cycle (ID 1746): No data returned
#    ✔ Demand (ID 1293): 1440 rows
#
# 💾 Saved successfully to /content/drive/MyDrive/Deep Learning/Project 2/Spain/spain_energy_generation_from_2025-10-30T23-59-59_to_2025-11-09T23-59-59.csv
#
# ⌚ Processing Data from 2025-10-20T23:59:59 to 2025-10-30T23:59:59...
#
# 📥 Downloading data for: ['Total Generation', 'Solar PV', 'Solar Thermal', 'Wind', 'Nuclear', 'Hydro', 'Coal', 'Gas Combined Cycle', 'Demand']
#    ✔ Total Generation (ID 10004): 1446 rows
#    ✔ Solar PV (ID 1295): 1446 rows
#    ✔ Solar Thermal (ID 1294): 1446 rows
#    ✔ Wind (ID 551): 1446 rows
#    ✔ Nuclear (ID 549): 1446 rows
#    ✔ Hydro (ID 546): 1446 rows
#    ✔ Coal (ID 547): 1446 rows
#    ⚠️ Gas Combined Cycle (ID 1746): No data returned
#    ✔ Demand (ID 1293): 1446 rows
#
# 💾 Saved successfully to /content/drive/MyDrive/Deep Learning/Project 2/Spain/spain_energy_generation_from_2025-10-20T23-59-59_to_2025-10-30T23-59-59.csv
